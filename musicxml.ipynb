# %%
#C:/Users/charl/Documents/OM#/temp-files/Python/Scripts/python.exe
import music21 

#xml_file = m21.converter.parse("C:/Users/charl/OneDrive_usp.br/Documents/OpenMusic/in-files/Turvo-Turvo.xml")
xml_file = music21.converter.parse("C:/Users/charl/OneDrive_usp.br/Documents/OpenMusic/in-files/test.xml")
    
quantas_partes = len(xml_file.parts)


for part_index in range(quantas_partes):
    measures = xml_file.parts[part_index].getElementsByClass(music21.stream.Measure)
    quantos_compassos = len(measures)
    for measure_index in range(quantos_compassos):
        
        # ==============================================
        notes = measures[measure_index].getElementsByClass(music21.note.Note)
        xml_dynamics = measures[measure_index].getElementsByClass(music21.dynamics.Dynamic.value)
        quantas_notas = len(notes)

        for note_index in range(quantas_notas):               
            
            note_with_index = notes[note_index]
           
            # Durations e tempo
            duration = note_with_index.duration
            tuples = duration.tuplets
            ratio = duration.aggregateTupletMultiplier() 
            have_dots = duration.dots
            type_of_note = duration.type
            
            # Pitch
            pitch = '{}{}'.format(note_with_index.name, note_with_index.octave)
            print('Note: ', pitch)
            print('\n')
            
            
            # Dynamics
            print('Dynamics', xml_dynamics)
            print('\n')
            

            # Articulations
            print('Articulations: ', note_with_index.articulations)
            print('\n')

            # Note head
            print('NoteHead: ', note_with_index.notehead)
            print('\n')
            print('-----------------------------------------------------')

# TODO 
# 1. Conseguir informação de qual nota caberia normalmente (por exemplo, é a nota 32 ou 16, etc)
# 2. Conseguir informação sobre Dinamicas.
# 3. Conseguir informação sobre texto. (CENTS)
# Out:
# Note:  F4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  A#4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  B-4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  [<music21.articulations.Staccato>]
#
#
# NoteHead:  diamond
#
#
# -----------------------------------------------------
# Note:  E-5
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  F4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  B-4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  E5
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.1 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  F4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.2 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  F4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.2 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
# Note:  B-4
#
#
# Dynamics <music21.stream.iterator.StreamIterator for Measure:m.2 @:0>
#
#
# Articulations:  []
#
#
# NoteHead:  normal
#
#
# -----------------------------------------------------
